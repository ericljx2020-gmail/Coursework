# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.rnn = nn.RNNCell(self.input_size, self.hidden_size)
        self.fc = nn.Linear(self.hidden_size, self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.rnn(input, hidden)
        output = self.fc(hidden)


        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (rnn): RNNCell(100, 100)
#   (fc): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
# NOTE: You may reduce the number of training iterations if the training takes long.
iters       = 13000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/13000 loss:3.3347835540771484
# generated sequence: WrN teitkinRt eoae tDtotloEAr ,e mUee R me
# CaPa god we eI
# ?elLtiuem Uensa pRue sh.; re volts uggLdet
#
# iter:199/13000 loss:2.751380443572998
# generated sequence: WheleissCyov, oul;.WfeodaY, fpasydsd!ve sis;
# I:
# Tha:
# Mot whesd dortrstewe y;twnc oncind maty UIes RTo
#
# iter:299/13000 loss:2.4867095947265625
# generated sequence: Wwesteetand heat ws wuoirie pu poave-ce.
#
# Mxk Azkerded sthe?
# pad the;
# The ha Dhesen myor the netos sh
#
# iter:399/13000 loss:2.387056589126587
# generated sequence: WALdderuse, irt bis sa ands -I no yif yoneas. hor! ImeU it io, , in ald, tho dige;
# Bo anew or ay tee
#
# iter:499/13000 loss:2.3347396850585938
# generated sequence: WJ's ofbe do dolt ertelasd rowlly totprethen hit fofand annd wote hat noule joves ayd meas whim in th
#
# iter:599/13000 loss:2.3024885654449463
# generated sequence: Wirw,
# sinn
# Lrfres,
# Ans hat lenghor; of Ly k st nst sfimk;
# Isis all andich
# Bu say, in te and de!
#
# Y:w,
#
# iter:699/13000 loss:2.2507498264312744
# generated sequence: Wing.
# Bewall gerson io so meren hay thay,er, sory, atenes ous
# dowcrise ines nomy beok ef, a sid uwt b
#
# iter:799/13000 loss:2.221665859222412
# generated sequence: Winge,
# And.
#
# INGENUS:
# Co thim to lracr I land haik it arr phith mirlifs io noulf Gere woll, whethay!
#
# iter:899/13000 loss:2.20337176322937
# generated sequence: Wtant An:
# Ay no uth shat ar
# Oy Ro kik cour, at wins I mowh fio an saintie be withere Ofath.
#
# EDOELES:
#
# iter:999/13000 loss:2.166414499282837
# generated sequence: Wery so elitstornd shath.
#
# HORKENSSaGDLO:
# Nrom cumenos Bam of hest,
# I Thom I keck thaed mortodr.
#
# GRL
#
# iter:1099/13000 loss:2.1334431171417236
# generated sequence: Whon hemise.
#
# ROPENLESSMENRIXEN:
# Hy grame ppaee dock your morer:
# Whewe neve come ous.
# Tquins?
# .
# Spavi
#
# iter:1199/13000 loss:2.122174024581909
# generated sequence: What loe, powgut, worde forest.
# Wim be to you no you rory siskaras thingelaking, beatone Ke? oull, no
#
# iter:1299/13000 loss:2.119673252105713
# generated sequence: WAod
# Kate:
# To rosmetepowhstr?
#
# Kpof toued? not blise ald you kowe owet mad sray;
# Bytteeds, Iw t of ot
#
# iter:1399/13000 loss:2.063314437866211
# generated sequence: Whave saurt anlso thele I'p
# Gowssiousteence, winsw mo soutes
# Gurn thou oforn our that the will mely h
#
# iter:1499/13000 loss:2.0704758167266846
# generated sequence: We chnonh me aa have matianthy aid, apsustrk: I full be be the be to horg.
#
# PSicINGER:
# Rise: I beke d
#
# iter:1599/13000 loss:2.121610403060913
# generated sequence: Whoug: proulimsh: belemth:
# Rutien Sounn:
# Thy Jfurth ta the hive founse, you fall, the plomanomes,
# A'd
#
# iter:1699/13000 loss:2.0740976333618164
# generated sequence: WI seremmur mosh ploou'mt in I haveat nearess arath, the buth!
# But my he ppay ladd be aperin, anf as
#
# iter:1799/13000 loss:2.0861644744873047
# generated sequence: WARd pald my well broutyind good a dome moter's cansarene, the bre, fother' brow, braw Mar come the c
#
# iter:1899/13000 loss:2.067976236343384
# generated sequence: Weet restd comoucl mine:
# Ores with
# As not panbenn by wine but she halt! ngemensps amar shork but for
#
# iter:1999/13000 loss:2.0529749393463135
# generated sequence: Wellon his namchedger thee, coutwerugan.
# Thouns conee and?T Crefore that is in cut abchin; Bume; were
#
# iter:2099/13000 loss:2.0458807945251465
# generated sequence: Well?y and thou give Aok erours Poin
#  heped ur you?
#
# SimZEO:
# All the verr to my to than wor tole our
#
# iter:2199/13000 loss:2.0156846046447754
# generated sequence: WARD Crownt rist yee;
# Gow thill peicher His, wace ruace
# jite.-
# Liok,, nood no
# tut hibby.
#
# BEDHARD:
# O
#
# iter:2299/13000 loss:2.0317955017089844
# generated sequence: WARDA:
# I not dosher,
# Dace lew, thy leace spoingem!
#
# BGAPET:
# Sel scarnten? with theich at encle his we
#
# iter:2399/13000 loss:2.0271217823028564
# generated sequence: WARD Ir PUNCELACH:
# O selly gidit thim jodrarsey; neterine the irmy horman they where true; bict, if m
#
# iter:2499/13000 loss:2.0118675231933594
# generated sequence: Wand, ardy Wall you: like od as Perightlo;
# So.
#
# TADY VINCE:
# Weal is deray. Comerre my kear and eils,
#
#
# iter:2599/13000 loss:2.02799391746521
# generated sequence: WARD OV:
# No mise mogly at ing sickle!
#
# KIN NIUS:
# And soltt aby swant bet,
# Prickecalomee it no' for
# wh
#
# iter:2699/13000 loss:1.9919806718826294
# generated sequence: WI shaunryoured ssly;
# You shing fow an our like whow of your in you daven bedim?
#
# BEROMIO:
# Ingo heed
#
# iter:2799/13000 loss:2.0016391277313232
# generated sequence: W:
# And dishersud and deth him wilt brench ther -te so dood with and whath gince in to stay heal dind:
#
# iter:2899/13000 loss:1.9590377807617188
# generated sequence: Whim weessue.
#
# JSe NI:
# Hive of hearicll.
# Nionter: Dike,
# As urdo,
# Yot a bit wist be tbeed to in e whis
#
# iter:2999/13000 loss:1.9672013521194458
# generated sequence: Wiff Will the dey trow mos son wy trouselise thue deff to metry neoventert,
# I ol, in sweime bispy O p
#
# iter:3099/13000 loss:1.9496515989303589
# generated sequence: With, ay? Bevisingres, ade to sand wateerseds ove as shath; a'llalisuled to methan, dail have shall u
#
# iter:3199/13000 loss:1.962015986442566
# generated sequence: Whow it yessial.
#
# KING HENR:
# Yoy if thy bear I hath ray.
#
# ISABEL:
# Me ware I oung livink net a brept,
#
# iter:3299/13000 loss:1.9694700241088867
# generated sequence: Wher, the our digher, a matien ant tist
# Of in yould-hish rlder bitword:
# I'd him;
# Thesomted-sim joy th
#
# iter:3399/13000 loss:1.9930068254470825
# generated sequence: Way selle that to thus dear lets.
#
# PERERIA:
# To tue the draze,
# st sextiop: soose of BrUCEP, Kach of Ca
#
# iter:3499/13000 loss:1.9593786001205444
# generated sequence: Will brawnle bonE by far you stree a ramo?
# UpTody leserold bestatl, thinks, and
# And this we consby.
#
#
#
# iter:3599/13000 loss:1.9351519346237183
# generated sequence: Wints a, prows hor a kelp ast nome of him to smact:
# Bitcamquet
# seats
# Bustle!
#
# TARENTIO:
#
# Ke Wastly le
#
# iter:3699/13000 loss:1.9435991048812866
# generated sequence: Wenter, buman stiel forler For hosenter's. wild.
#
# MENCE:
# Noo some to trash bear I have yee werd this
#
# iter:3799/13000 loss:1.9221032857894897
# generated sequence: WARd oursell'se;
# Harrave mare's by save ip a lave, I groige frionceedy;
# Gent,
# Angelse ty to give that
#
# iter:3899/13000 loss:1.9152767658233643
# generated sequence: WARd of rive to unsees.
#
# GLOUTENCIO:
# Is spanmirifeep'ly und buhtne seip;
# The best you mustinoble?
#
# Fi
#
# iter:3999/13000 loss:1.9380378723144531
# generated sequence: With siny me chin! hake?
# I the nom.
#
# DUKE VIWh a her go And firthild with some hat:
# Which as chmorr,
#
# iter:4099/13000 loss:1.9171720743179321
# generated sequence: Wirk to geast Dand for giad'eed Bedithenon yoursens,
# Withiel; pain, geack you liply and battrouss not
#
# iter:4199/13000 loss:1.934744119644165
# generated sequence: W:
# His,
# Lith, latuil,
# And upbord we?
# 'regliess nighter spent. OL nate bured lencersp;
# A'd anden but h
#
# iter:4299/13000 loss:1.908191442489624
# generated sequence: With to guch shally:
# True knower, my sleant
# Than I plailf and soth how do survicherster work.
#
# POLLOU
#
# iter:4399/13000 loss:1.9063349962234497
# generated sequence: Whers; ang a mave like me seake bread.
#
# CAUCIIT:
# Ant
# y makeee rone leacluticuse sumpes
# brot fure in w
#
# iter:4499/13000 loss:1.9206914901733398
# generated sequence: WARD IV:
# Nill, op to degiout of born of thou gaitionard we hor at o' us of it off thous to doagh't ou
#
# iter:4599/13000 loss:1.9494891166687012
# generated sequence: WICKING LASIO:
# God all thim thetesand in head lost herdes; yelms,
# And not thee same talk. I tlach nam
#
# iter:4699/13000 loss:1.912166953086853
# generated sequence: W:
# Wheremorelaughtliempractonat to the oused my worece,
# Woth othee have thougized;
# O, are and dithger
#
# iter:4799/13000 loss:1.9358361959457397
# generated sequence: Was lorixe uforse.
#
# A VINCENTIO:
# A our purie.
#
# MANGINIS:
# Ay thile me, lord?
#
# ERCIUS:
# How the parese?
#
# iter:4899/13000 loss:1.9113999605178833
# generated sequence: WARWORD mike surse?
#
# Fan the lord destice to she wandee,
# You much, takes.
#
# PETLANLE:
# Who gueted perfa
#
# iter:4999/13000 loss:1.8831515312194824
# generated sequence: WARE VINGENSIO:
# Tood''d womtifongitivesiet in com the respam staked: shall loven, anast you not it no
#
# iter:5099/13000 loss:1.9015995264053345
# generated sequence: WARGow,
# Hof dest dheels.
#
# ANTENENCA:
# I thy vore for hand hos oiet,
# To be; and well.
#
# DUKE OF MERBY:
# T
#
# iter:5199/13000 loss:1.9153257608413696
# generated sequence: W:
# Your
# lont.
#
# RIVEMAN:
# All not this,
# Mattantichave.
# Ye seece,
# Haven to my for of the have that wo ma
#
# iter:5299/13000 loss:1.927585244178772
# generated sequence: Wispt, witu
# The days of all you smarily, be.
#
# PROWIS-X: in say, no shath hrasadt, For the cour thy se
#
# iter:5399/13000 loss:1.8994280099868774
# generated sequence: We thy crased our gonith me this your fan thes,
# Wet wart' nither
# Mas Ever my extr extild make hear an
#
# iter:5499/13000 loss:1.8823797702789307
# generated sequence: Warr it. give tif where
# Rome.
#
# PSTOLY:
# Tis! it is clund
# Tudy he? you denose's be timnolfus him, still
#
# iter:5599/13000 loss:1.8983619213104248
# generated sequence: With say, have a feard fow shist my read fow thy neper, will
# Where the erputs aw I aw see in repach m
#
# iter:5699/13000 loss:1.9227815866470337
# generated sequence: WARD IId:
# My mared,
# Some gone your them?
# His my mores; then he have resing
# thin the wall fatad's well
#
# iter:5799/13000 loss:1.8915826082229614
# generated sequence: WARIS:
# what whow of have there-thing, abrignt be naterow and there hi paing tho dreward, wild
# To dait
#
# iter:5899/13000 loss:1.861572027206421
# generated sequence: Whe know and nibt, at mone as a
# sourt newingen, and wagcteld stengent tit loveaton'd when strusless a
#
# iter:5999/13000 loss:1.9053291082382202
# generated sequence: Whwas's wembiesty-
# Orow to thom oy
# Go.--
# Ay, mast iter moried il,
# and at his;
# Thing
# dean
# Ou hatl tell
#
# iter:6099/13000 loss:1.9072917699813843
# generated sequence: WARDIAGMAUDIO:
# O couns, art porders for in twas fat in the muny thist on af praid mith, farmatling br
#
# iter:6199/13000 loss:1.8664735555648804
# generated sequence: Why,
# Dis nothed
# And be you weghitio kingtt you stade thy hour, crulinge not to had me stad
# Mad hence.
#
# iter:6299/13000 loss:1.8542319536209106
# generated sequence: Where?
# 'Stent's ow no seaw,
# To wetter thamely you wey we the this my seipl Edwing same give them thou
#
# iter:6399/13000 loss:1.8786487579345703
# generated sequence: WAy
#
# BENVOLIO:
# I codemed wooldse, say;
# And mest vere ip'd, these be do,' thougs Marroun, famen
# Of gaz
#
# iter:6499/13000 loss:1.8817602396011353
# generated sequence: WARDIA:
# A dain,
# Rice.
# His not I bolds not swill
# brecl:
# Seachbly.
#
# First Slaw, one mer but fuck him co
#
# iter:6599/13000 loss:1.8811399936676025
# generated sequence: WARD II:
# Go, the distoly to my wite im dalk mean me, mikely na deveerder: let my Suepe suctlste spaty
#
# iter:6699/13000 loss:1.8775997161865234
# generated sequence: Was urours yout tour cyor tondser:
# You be merum.
#
# LEONIO:
# I amno
# Frevatinn ane whet loved Eng know in
#
# iter:6799/13000 loss:1.884018063545227
# generated sequence: Where my hill,
# Tall there durse nif prive hear of.
# Whitse you.
# Lood Slaste hit neake!
# -roisited train
#
# iter:6899/13000 loss:1.8673015832901
# generated sequence: Withwer st. Valee iftiont so thin
# wos led to haves of that to--
# Verunter right you kniely verto your
#
# iter:6999/13000 loss:1.875821828842163
# generated sequence: Whepo''t to the earthe enveritatech'starest, in our, sing of the hand of this themany,
# Or Ellorder? I
#
# iter:7099/13000 loss:1.849031925201416
# generated sequence: WI't my live of one all recars,
# Ay,
# Let your my the cammasthentadent:
# Thougs I shalts;
# The noble to h
#
# iter:7199/13000 loss:1.8716177940368652
# generated sequence: Will call!
# As,
# Gole of utouts tanear on withis leow;
# What? faiven sir, beath sin seach my life; it fo
#
# iter:7299/13000 loss:1.8775691986083984
# generated sequence: Wst;
# Theilf. Them she holddice
# thein ence heres;
# Thou in honour it,
# And, hege dittter'd ieling, nir,
#
# iter:7399/13000 loss:1.8658028841018677
# generated sequence: Wherewnyed mine the kill I there your hon me,
# Fothered-both I much trould a vanitely lied come,
# For t
#
# iter:7499/13000 loss:1.842607855796814
# generated sequence: Whis astrray
# Leateds a buclimias me tock
# Tofrots-then
# At whow to conteation hofeos tow, and bhatho to
#
# iter:7599/13000 loss:1.8513686656951904
# generated sequence: Way, gons good Cothounds in a prast,
# What.
#
# VINCENTIO:
# Olaty toot you prong-
# Ind age crixse sheper: t
#
# iter:7699/13000 loss:1.8554612398147583
# generated sequence: Weine.
# Shall back, In exite.
# As you sillagule
# That will, and sly back bese why exays of Yew
# Far not s
#
# iter:7799/13000 loss:1.851880431175232
# generated sequence: WARd:
# My Saimbes,
# Ed thy drgats for a
# vene
# Trect in to dale see take
# That the hamh that seagh, who er
#
# iter:7899/13000 loss:1.8692965507507324
# generated sequence: Wartmens.
#
# QUEEN ELMERINA:
#
# D INSATHAND:
# Wheress evelly.
# Cant
# Than spreatn.
#
# QUEEN:
# As armiob-dend li
#
# iter:7999/13000 loss:1.8394345045089722
# generated sequence: Was
# Lord.
#
# PiOvel til would and go my canamest is nor wimple's.
#
# CAMILLO:
# You mest, leave and Fiflumi
#
# iter:8099/13000 loss:1.8553214073181152
# generated sequence: With hore at exces are whoughary a pleath your foury very very heariser anad and the sworther ofe.
# We
#
# iter:8199/13000 loss:1.865256667137146
# generated sequence: Where me mawe the seav gren not ligh aro a miles embur with to heve-nen as thy ast, myur me
# Though, t
#
# iter:8299/13000 loss:1.850517988204956
# generated sequence: WARD, hais; wordich as, gense very in theaked und, our body?
# When anme?
#
# LUCENTIO:
# E wince a graverbl
#
# iter:8399/13000 loss:1.8377985954284668
# generated sequence: Wat men:
# And moes where.
#
# SeT:
# That blat!
#
# QULE
# Sor And fing had bott.
#
# ONDELLO:
# See And cire seet de
#
# iter:8499/13000 loss:1.8542225360870361
# generated sequence: Wwe thumeess, Hirguthise michadinowe him
# The Laired me, shim.
#
# PithINy Murve of this romain.
#
# DUCHESS
#
# iter:8599/13000 loss:1.8550349473953247
# generated sequence: Which bud
# go befee, did, goothy that notarmy.
#
# LEONTESBEO:
# Hing then thou hereiuntyer they ho shap he
#
# iter:8699/13000 loss:1.8533202409744263
# generated sequence: Wheringed sInes, pursce, head, reave, burby bruage to atchers I servey, hir, pellous: was hapherd and
#
# iter:8799/13000 loss:1.8464314937591553
# generated sequence: WI sweab.
# His, cirsh.
#
# RICHARD IF:
# To shall; come on hese usorss forits?
#
# ANFOLA:
# And not!
# You, our w
#
# iter:8899/13000 loss:1.8242228031158447
# generated sequence: WARGIA:
# Es of chother he hose on
# Beople my lording the tright, con it will stoucees;
# For Edcens age m
#
# iter:8999/13000 loss:1.8385463953018188
# generated sequence: Wis she bloody morishal to eesly day, till lee unoneevion.
#
# ESCALUS: come, and ho dithouch He vicking
#
# iter:9099/13000 loss:1.8293781280517578
# generated sequence: With ear be. Four.
# To was.
# They plerse.
#
# ED IV:
# Whying:
# To dod searn's pus us he's must to froming re
#
# iter:9199/13000 loss:1.8046467304229736
# generated sequence: What wate:
# Welte he, with ow his roent.
#
# ROMEO:
# Catle
# Haiguss, and yey mate mesese that whose pesteom
#
# iter:9299/13000 loss:1.8403619527816772
# generated sequence: Wought than meive, grepint nate-to suman this more are prain may,--hath!
# She seugh of Fixto
# lengenuld
#
# iter:9399/13000 loss:1.8284531831741333
# generated sequence: Wo have down! all to make sorfe you more sogeed to be tolas, too d smipe it,
# To the tere it.
#
# TUCHIAR
#
# iter:9499/13000 loss:1.8646060228347778
# generated sequence: Warm and lord his not the pertious death and man
# Ave
# With too, follids do'p?
# We steates, bear of to a
#
# iter:9599/13000 loss:1.8536571264266968
# generated sequence: Wo, too mer puigeast not our hainone the lods murt
# In will tey in ingady in we mentit.
#
# BRUTUS:
# No
# Sw
#
# iter:9699/13000 loss:1.8123724460601807
# generated sequence: WI lords treelces are thou's a touls herwen you good your a, come able! that stake!
# His, who chas sow
#
# iter:9799/13000 loss:1.8429136276245117
# generated sequence: What wement,
# That. Eyes fair so'ters who her peorenss liok bo he patded tends, trest I froth statess.
#
# iter:9899/13000 loss:1.8652117252349854
# generated sequence: Where
# Thus mither I what doubeprech'd be conquee:
# Ay in meenuty yours;
# But te rese heavond pooch doth
#
# iter:9999/13000 loss:1.8036713600158691
# generated sequence: Wey, carry, him; beger; it his.
#
# TOMENES:
# Ay swear ours and forth if all
# Mupt mite
# Which my fould but
#
# iter:10099/13000 loss:1.833270788192749
# generated sequence: What is coolous whire ods with sparius.
# Properear.
# O what a deture the whis, but the lord:
# A umorld t
#
# iter:10199/13000 loss:1.807626485824585
# generated sequence: Where my fell condingming a doute and I sird.
#
# AUFIDIUSIA:
# O alk pate the fare't figst not a swatks b
#
# iter:10299/13000 loss:1.827605128288269
# generated sequence: Whings;
# But these, bet's his cars most, and now oke heagtiond,
# Ahine grincly, whintaints:
# Ay hather i
#
# iter:10399/13000 loss:1.8356815576553345
# generated sequence: Wards:
# Her'm.
#
# ThiDd LIONA:
# What if morn with your deabue oing his  trauning.
#
# ARCIES:
# Hen I would th
#
# iter:10499/13000 loss:1.851574182510376
# generated sequence: Whereing third and grie; I not Moss all you thus to steet; kamen gromned for not childr
# Boot my seave
#
# iter:10599/13000 loss:1.8562368154525757
# generated sequence: Will deed thee theelies.
#
# KING EDWASPAbbrets soum if more;
# And fone see you; a paling potentery! voot
#
# iter:10699/13000 loss:1.8428688049316406
# generated sequence: Wore,
# O, I It addinghing he dather,
# Horter vatlenche of she host to gally to itage.
#
# BENSIO:
# Indeary,
#
# iter:10799/13000 loss:1.8344794511795044
# generated sequence: Was I'll mone unguen the celd us in the breed herous
# I wands' the friend will will hid so life,
# you w
#
# iter:10899/13000 loss:1.8090338706970215
# generated sequence: Wh proous of this nomp, to my is prepint
# then wilks life!
# O, with nadn, till's like
# Frventy.
# Glotwens
#
# iter:10999/13000 loss:1.8171683549880981
# generated sequence: Why.
#
# CORTENTUS:
# Now till!
#
# PRINCE:
# Dielies tadr
# And follow
# The ervergar, good begeatiom eiging stect
#
# iter:11099/13000 loss:1.8212178945541382
# generated sequence: Was his.
#
# LUTUS:
# Good reck?
#
# RICHARD: Aar grotcked tost--
#
# Ghost lod unt t word the bid grow'
# cherry,
#
# iter:11199/13000 loss:1.8402900695800781
# generated sequence: We all
# Will
# Thas if thy, our,
# Wheresouse fromghant
# And coufinh he earth and of you in homen;
# Or. Jong
#
# iter:11299/13000 loss:1.8148127794265747
# generated sequence: Whereder a boles, if comest? Garwising mewn not, a' thy laugh, sir, is poor untweea a kistites not, w
#
# iter:11399/13000 loss:1.8442844152450562
# generated sequence: Whear hall it right for Erund night may four.
#
# MRMTISly, naw your frum. O blate of angure most of tru
#
# iter:11499/13000 loss:1.8163089752197266
# generated sequence: What, not our life,
# The mode?
# Well.
#
# MUREd:
# Ay his priptice of Harwart of Atrest vid think had him fo
#
# iter:11599/13000 loss:1.8001502752304077
# generated sequence: We may at in the caurt jurghty the iding ingdauses whed? For andage,
# Than to the deanthis,
# Ahin teall
#
# iter:11699/13000 loss:1.8293681144714355
# generated sequence: Well ever leave a dozen and midd all there his wish in sin end nor him: for
# ovenes
# Of 'Twa liort of t
#
# iter:11799/13000 loss:1.8123266696929932
# generated sequence: Warm faged store are.
# An for houraan:
# If to deep thou digst shamh,
# And stead me of hear id op ygulies
#
# iter:11899/13000 loss:1.8033000230789185
# generated sequence: Where woy you sir, which I moot him let he dight the riges
# May soullatel of to replem be bid this the
#
# iter:11999/13000 loss:1.830169916152954
# generated sequence: Wit his dre an shorce,
# Posenteb.
# It let, or put to feam me.
#
# So, all noble would stongst:
# Looghter's
#
# iter:12099/13000 loss:1.8051056861877441
# generated sequence: Was 'drathol make your discauntrony coust pely
# Shame ock oqus?.
# So.
#
# GLOUCESTER:
# I yovemberiony, a Ro
#
# iter:12199/13000 loss:1.7844637632369995
# generated sequence: Wet!
#
# TRANTIS:
# That I till my lord
# That quangein know not look me, which I ladfian of some marriet
# An
#
# iter:12299/13000 loss:1.7680246829986572
# generated sequence: Witht all, who do lies
# for trum:
# This shade, my grear longs a dieft us him fol; noe cautud whichoutly
#
# iter:12399/13000 loss:1.82501220703125
# generated sequence: Wherunen at faterter!
#
# KING RICHARD II:
# Ext but he Right, as aur than, laar Jeegs with him say
# blace:
#
# iter:12499/13000 loss:1.8109703063964844
# generated sequence: Wise paint daw-handly and upated your ourse thas onore.
# A, will'd dissard-sinds murrielors.
#
# TRANIO:
#
#
# iter:12599/13000 loss:1.826230525970459
# generated sequence: Wich light preath.
#
# WARWICK:
# And Tyou hepe a prevald morterd sir; not queet everire iglose of for a'k
#
# iter:12699/13000 loss:1.8171955347061157
# generated sequence: WI he contagling o' fills. comes.
#
# QUEEN MARGLO:
# Extull Hences
# And and see; nid as forges.
#
# KING
# RICH
#
# iter:12799/13000 loss:1.796406626701355
# generated sequence: Well crowh frack'st man hose the Pad se put:
# Prest or not aged First to the lord.
# Is; I love variar f
#
# iter:12899/13000 loss:1.8297288417816162
# generated sequence: Will the sha to Cicots as is day.
#
# AEN HaR:
# I not this Clowny not a thou chal hay prange my masty of
#
# iter:12999/13000 loss:1.7909754514694214
# generated sequence: Wheares you look think:
# Why protion
# To thee hus aginn ala bestas's blow e I may, 'trapcrd; harthy.
# I

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot([loss.cpu().item() for loss in all_losses])
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# What shade
# prood wo?
# Counspy, by he lord.
#
# MUCIES:
# Pitil
# wotous take mroud Edward to tould this my lords onst,
# But 'Teak he go hous my pery awanch witring.
#
# DUKE
# LARDONMAS
# OMPET:
# Thou, gowdren will save I their hang morenling.
# Could but 'Ang to Ye;
# For my hases, lork, brost I new courd bot's dureno all to stroce aft misication.
# That asp;
# No flams a hondy naw his toor swind, lick:
# And,
# This shusbanos
# In presing they
# Freat male lid secenter; matter afhee,
# Thyselp parn;
# Fome in you poble take could; as groctry be a could do go onforth with'd to thy eact thy ding,
# And I muchard the pathang,
# And.
#
# D
